# %% [markdown]
# <a href="https://colab.research.google.com/github/daemonX10/Generative-Deep-Learning/blob/main/DGGAN_Pytorch_%26_Keras.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow.keras import (
    layers,
    models,
    callbacks,
    losses,
    utils,
    metrics,
    optimizers,
)

# %%
def sample_batch(dataset):
    batch = dataset.take(1).get_single_element()
    if isinstance(batch, tuple):
        batch = batch[0]
    return batch.numpy()


def display(
    images, n=10, size=(20, 3), cmap="gray_r", as_type="float32", save_to=None
):
    """
    Displays n random images from each one of the supplied arrays.
    """
    if images.max() > 1.0:
        images = images / 255.0
    elif images.min() < 0.0:
        images = (images + 1.0) / 2.0

    plt.figure(figsize=size)
    for i in range(n):
        _ = plt.subplot(1, n, i + 1)
        plt.imshow(images[i].astype(as_type), cmap=cmap)
        plt.axis("off")

    if save_to:
        plt.savefig(save_to)
        print(f"\nSaved to {save_to}")

    plt.show()

# %%
IMAGE_SIZE = 64
CHANNELS = 1
BATCH_SIZE = 128
Z_DIM = 100
EPOCHS = 300
LOAD_MODEL = False
ADAM_BETA_2 = 0.5
LEARNING_RATE = 0.0002
NOISE_PARAM = 0.1

# %%
# !kaggle datasets download -d joosthazelzet/lego-brick-images
# Out:
# Dataset URL: https://www.kaggle.com/datasets/joosthazelzet/lego-brick-images
# License(s): GPL-2.0
# Downloading lego-brick-images.zip to /kaggle/working
#  99%|██████████████████████████████████████▋| 0.99G/1.00G [00:08<00:00, 134MB/s]
# 100%|███████████████████████████████████████| 1.00G/1.00G [00:08<00:00, 123MB/s]

# %%
# !unzip lego-brick-images.zip -d /kaggle/working/
# Out:
# Archive:  lego-brick-images.zip
#   inflating: /kaggle/working/Collada models/14719 flat tile corner 2x2.dae
#   inflating: /kaggle/working/Collada models/15672 roof tile 1x2.dae
#   inflating: /kaggle/working/Collada models/18654 beam 1M.dae
#   inflating: /kaggle/working/Collada models/2357 brick corner 1x2x2.dae
#   inflating: /kaggle/working/Collada models/2420 plate corner 2x2.dae
#   inflating: /kaggle/working/Collada models/2780 Peg with friction.dae
#   inflating: /kaggle/working/Collada models/27925 flat tile round 2x2.dae
#   inflating: /kaggle/working/Collada models/3001 brick 2x4.dae
#   inflating: /kaggle/working/Collada models/3002 brick 2x3.dae
#   inflating: /kaggle/working/Collada models/3003 brick 2x2.dae
#   inflating: /kaggle/working/Collada models/3004 brick 1x2.dae
#   inflating: /kaggle/working/Collada models/3005 brick 1x1.dae
#   inflating: /kaggle/working/Collada models/3010 brick 1x4.dae
#   inflating: /kaggle/working/Collada models/3020 plate 2x4.dae
#   inflating: /kaggle/working/Collada models/3021 plate 2x3.dae
#   inflating: /kaggle/working/Collada models/3022 Plate 2x2.dae
#   inflating: /kaggle/working/Collada models/3023 Plate 1x2.dae
#   inflating: /kaggle/working/Collada models/3024 plate 1x1.dae
#   inflating: /kaggle/working/Collada models/3037 roof tile 1x4.dae
#   inflating: /kaggle/working/Collada models/3038 roof tile 2x3.dae
#   inflating: /kaggle/working/Collada models/3039 roof tile 2x2.dae
#   inflating: /kaggle/working/Collada models/3040 roof tile 1x2.dae
#   inflating: /kaggle/working/Collada models/3045 roof corner outside tile 2x2.dae
#   inflating: /kaggle/working/Collada models/3046 roof corner inside tile 2x2.dae
#   inflating: /kaggle/working/Collada models/3062 Round Brick 1x1.dae
#   inflating: /kaggle/working/Collada models/3063 Curved Brick 2 Knobs.dae
#   inflating: /kaggle/working/Collada models/3068 flat tile 2x2.dae
#   inflating: /kaggle/working/Collada models/3069 Flat Tile 1x2.dae
#   inflating: /kaggle/working/Collada models/3070 Flat Tile 1x1.dae
#   inflating: /kaggle/working/Collada models/3298 roof tile 2x3.dae
#   inflating: /kaggle/working/Collada models/33909 plate 2 knobs 2x2.dae
#   inflating: /kaggle/working/Collada models/3622 brick 1x3.dae
#   inflating: /kaggle/working/Collada models/3623 Plate 1x3.dae
#   inflating: /kaggle/working/Collada models/3659 brick bow 1x4.dae
#   inflating: /kaggle/working/Collada models/3675 roof tile outside 3x3.dae
#   inflating: /kaggle/working/Collada models/3700 Technic Brick 1x2.dae
#   inflating: /kaggle/working/Collada models/3794 Plate 1X2 with 1 Knob.dae
#   inflating: /kaggle/working/Collada models/4150 flat tile round 2x2.dae
#   inflating: /kaggle/working/Collada models/41677 lever 2M.dae
#   inflating: /kaggle/working/Collada models/41678 Cross Block Fork 2x2.dae
#   inflating: /kaggle/working/Collada models/4274 Connector Peg w Knob.dae
#   inflating: /kaggle/working/Collada models/4286 roof tile 1x3.dae
#   inflating: /kaggle/working/Collada models/43093 Bush 2M friction - Cross axle.dae
#   inflating: /kaggle/working/Collada models/43857 beam 1x2.dae
#   inflating: /kaggle/working/Collada models/4490 brick bow 1x3.dae
#   inflating: /kaggle/working/Collada models/54200 roof tile 1x1.dae
#   inflating: /kaggle/working/Collada models/6143 Brick D16 w cross.dae
#   inflating: /kaggle/working/Collada models/6632 lever 3M.dae
#   inflating: /kaggle/working/Collada models/85984 roof tile 1x2.dae
#   inflating: /kaggle/working/Collada models/99301 roof tile inside 3x3.dae
#   inflating: /kaggle/working/Collada models/maps/bump/3038_bump.png
#   inflating: /kaggle/working/Collada models/maps/bump/3039_bump.png
#   inflating: /kaggle/working/Collada models/maps/bump/3040_bump.png
#   inflating: /kaggle/working/Collada models/maps/bump/3045_bump.png
#   inflating: /kaggle/working/Collada models/maps/bump/3046_bump.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0001.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0002.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0003.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0004.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0005.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0006.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0007.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0008.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0009.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0010.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0011.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0012.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0013.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0014.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0015.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0016.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0017.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0018.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0019.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0020.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0021.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0022.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0023.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0024.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0025.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0026.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0027.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0028.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0029.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0030.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0031.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0032.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0033.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0034.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0035.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0036.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0037.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0038.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0039.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0040.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0041.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0042.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0043.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0044.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0045.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0046.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0047.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0048.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0049.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0050.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0051.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0052.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0053.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0054.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0055.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0056.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0057.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0058.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0059.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0060.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0061.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0062.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0063.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0064.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0065.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0066.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0067.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0068.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0069.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0070.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0071.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0072.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0073.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0074.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0075.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0076.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0077.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0078.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0079.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0080.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0081.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0082.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0083.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0084.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0085.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0086.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0087.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0088.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0089.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0090.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0091.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0092.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0093.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0094.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0095.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0096.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0097.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0098.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0099.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0100.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0101.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0102.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0103.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0104.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0105.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0106.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0107.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0108.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0109.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0110.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0111.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0112.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0113.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0114.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0115.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0116.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0117.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0118.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0119.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0120.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0121.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0122.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0123.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0124.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0125.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0126.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0127.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0128.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0129.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0130.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0131.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0132.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0133.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0134.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0135.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0136.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0137.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0138.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0139.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0140.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0141.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0142.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0143.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0144.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0145.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0146.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0147.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0148.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0149.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0150.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0151.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0152.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0153.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0154.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0155.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0156.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0157.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0158.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0159.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0160.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0161.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0162.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0163.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0164.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0165.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0166.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0167.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0168.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0169.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0170.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0171.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0172.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0173.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0174.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0175.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0176.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0177.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0178.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0179.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0180.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0181.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0182.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0183.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0184.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0185.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0186.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0187.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0188.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0189.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0190.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0191.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0192.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0193.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0194.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0195.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0196.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0197.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0198.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0199.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0200.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0201.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0202.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0203.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0204.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0205.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0206.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0207.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0208.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0209.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0210.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0211.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0212.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0213.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0214.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0215.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0216.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0217.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0218.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0219.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0220.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0221.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0222.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0223.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0224.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0225.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0226.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0227.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0228.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0229.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0230.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0231.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0232.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0233.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0234.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0235.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0236.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0237.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0238.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0239.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0240.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0241.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0242.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0243.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0244.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0245.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0246.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0247.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0248.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0249.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0250.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0251.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0252.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0253.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0254.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0255.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0256.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0257.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0258.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0259.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0260.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0261.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0262.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0263.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0264.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0265.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0266.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0267.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0268.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0269.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0270.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0271.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0272.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0273.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0274.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0275.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0276.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0277.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0278.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0279.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0280.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0281.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0282.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0283.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0284.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0285.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0286.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0287.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0288.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0289.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0290.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0291.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0292.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0293.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0294.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0295.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0296.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0297.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0298.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0299.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0300.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0301.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0302.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0303.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0304.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0305.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0306.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0307.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0308.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0309.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0310.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0311.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0312.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0313.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0314.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0315.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0316.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0317.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0318.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0319.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0320.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0321.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0322.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0323.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0324.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0325.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0326.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0327.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0328.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0329.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0330.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0331.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0332.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0333.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0334.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0335.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0336.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0337.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0338.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0339.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0340.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0341.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0342.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0343.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0344.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0345.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0346.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0347.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0348.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0349.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0350.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0351.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0352.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0353.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0354.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0355.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0356.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0357.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0358.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0359.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0360.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0361.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0362.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0363.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0364.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0365.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0366.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0367.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0368.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0369.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0370.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0371.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0372.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0373.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0374.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0375.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0376.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0377.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0378.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0379.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0380.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0381.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0382.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0383.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0384.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0385.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0386.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0387.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0388.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0389.png
#   inflating: /kaggle/working/LEGO brick images v1/11214 Bush 3M friction with Cross axle/201706171006-0390.png
# ...
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 294L.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 294R.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 295L.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 295R.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 296L.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 296R.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 297L.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 297R.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 298L.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 298R.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 299L.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 299R.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 300L.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 300R.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 301L.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 301R.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 302L.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 302R.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 303L.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 303R.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 304L.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 304R.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 305L.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 305R.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 306L.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 306R.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 307L.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 307R.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 308L.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 308R.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 309L.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 309R.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 310L.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 310R.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 311L.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 311R.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 312L.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 312R.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 313L.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 313R.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 314L.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 314R.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 315L.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 315R.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 316L.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 316R.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 317L.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 317R.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 318L.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 318R.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 319L.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 319R.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 320L.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 320R.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 321L.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 321R.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 322L.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 322R.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 323L.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 323R.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 324L.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 324R.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 325L.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 325R.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 326L.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 326R.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 327L.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 327R.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 328L.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 328R.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 329L.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 329R.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 330L.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 330R.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 331L.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 331R.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 332L.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 332R.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 333L.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 333R.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 334L.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 334R.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 335L.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 335R.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 336L.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 336R.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 337L.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 337R.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 338L.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 338R.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 339L.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 339R.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 340L.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 340R.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 341L.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 341R.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 342L.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 342R.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 343L.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 343R.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 344L.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 344R.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 345L.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 345R.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 346L.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 346R.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 347L.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 347R.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 348L.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 348R.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 349L.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 349R.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 350L.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 350R.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 351L.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 351R.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 352L.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 352R.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 353L.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 353R.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 354L.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 354R.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 355L.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 355R.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 356L.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 356R.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 357L.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 357R.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 358L.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 358R.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 359L.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 359R.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 360L.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 360R.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 361L.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 361R.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 362L.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 362R.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 363L.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 363R.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 364L.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 364R.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 365L.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 365R.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 366L.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 366R.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 367L.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 367R.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 368L.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 368R.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 369L.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 369R.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 370L.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 370R.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 371L.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 371R.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 372L.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 372R.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 373L.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 373R.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 374L.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 374R.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 375L.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 375R.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 376L.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 376R.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 377L.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 377R.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 378L.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 378R.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 379L.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 379R.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 380L.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 380R.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 381L.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 381R.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 382L.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 382R.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 383L.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 383R.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 384L.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 384R.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 385L.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 385R.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 386L.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 386R.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 387L.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 387R.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 388L.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 388R.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 389L.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 389R.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 390L.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 390R.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 391L.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 391R.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 392L.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 392R.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 393L.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 393R.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 394L.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 394R.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 395L.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 395R.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 396L.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 396R.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 397L.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 397R.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 398L.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 398R.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 399L.png
#   inflating: /kaggle/working/dataset/99301 roof tile inside 3x3 399R.png
#   inflating: /kaggle/working/validation.txt

# %%
import os

# List all directories in the working directory
working_dir = '/kaggle/working'
folders = [f for f in os.listdir(working_dir) if os.path.isdir(os.path.join(working_dir, f))]

# Print the number of folders and their names
print(f"Number of folders in {working_dir}: {len(folders)}")
print("Folders:", folders)
# Out:
# Number of folders in /kaggle/working: 4
# Folders: ['dataset', 'LEGO brick images v1', '.virtual_documents', 'Collada models']

# %%
train_data =  utils.image_dataset_from_directory(
    '/kaggle/working/dataset/',
    labels=None,
    color_mode = "grayscale",
    image_size = (IMAGE_SIZE,IMAGE_SIZE),
    batch_size = BATCH_SIZE,
    shuffle = True,
    seed =42,
    interpolation='bilinear'
)
# Out:
# Found 40000 files.

# %%
def preprocess(img):
    """
    Normalize and reshape the images
    """
    img = (tf.cast(img,"float32")-127.5)/127.5
    return img

train = train_data.map(lambda x:preprocess(x))

# %%
train_sample = sample_batch(train)

# %%
display(train_sample)

# %% [markdown]
# ![](https://idiotdeveloper.com/wp-content/uploads/2023/08/gan-1024x354.webp)

# %% [markdown]
# ![](https://idiotdeveloper.com/wp-content/uploads/2024/01/image.png)

# %%
discriminator_input = layers.Input(shape=(IMAGE_SIZE, IMAGE_SIZE, CHANNELS))
x = layers.Conv2D(64, kernel_size=4, strides=2, padding="same", use_bias=False)(
    discriminator_input
)
x = layers.LeakyReLU(0.2)(x)
x = layers.Dropout(0.3)(x)
x = layers.Conv2D(
    128, kernel_size=4, strides=2, padding="same", use_bias=False
)(x)
x = layers.BatchNormalization(momentum=0.9)(x)
x = layers.LeakyReLU(0.2)(x)
x = layers.Dropout(0.3)(x)
x = layers.Conv2D(
    256, kernel_size=4, strides=2, padding="same", use_bias=False
)(x)
x = layers.BatchNormalization(momentum=0.9)(x)
x = layers.LeakyReLU(0.2)(x)
x = layers.Dropout(0.3)(x)
x = layers.Conv2D(
    512, kernel_size=4, strides=2, padding="same", use_bias=False
)(x)
x = layers.BatchNormalization(momentum=0.9)(x)
x = layers.LeakyReLU(0.2)(x)
x = layers.Dropout(0.3)(x)
x = layers.Conv2D(
    1,
    kernel_size=4,
    strides=1,
    padding="valid",
    use_bias=False,
    activation="sigmoid",
)(x)

discriminator_output = layers.Flatten()(x)

discriminator = models.Model(discriminator_input,discriminator_output)
discriminator.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 64, 64, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 32, 32, 64)     │         1,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_4 (LeakyReLU)       │ (None, 32, 32, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 32, 32, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 16, 16, 128)    │       131,072 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 16, 16, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_5 (LeakyReLU)       │ (None, 16, 16, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 16, 16, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 8, 8, 256)      │       524,288 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 8, 8, 256)      │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_6 (LeakyReLU)       │ (None, 8, 8, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 8, 8, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_8 (Conv2D)               │ (None, 4, 4, 512)      │     2,097,152 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 4, 4, 512)      │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_7 (LeakyReLU)       │ (None, 4, 4, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 4, 4, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_9 (Conv2D)               │ (None, 1, 1, 1)        │         8,192 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 1)              │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,765,312 (10.55 MB)
#  Trainable params: 2,763,520 (10.54 MB)
#  Non-trainable params: 1,792 (7.00 KB)

# %%
generator_input = layers.Input(shape=(Z_DIM,))
x = layers.Reshape((1, 1, Z_DIM))(generator_input)
x = layers.Conv2DTranspose(
    512, kernel_size=4, strides=1, padding="valid", use_bias=False
)(x)
x = layers.BatchNormalization(momentum=0.9)(x)
x = layers.LeakyReLU(0.2)(x)
x = layers.Conv2DTranspose(
    256, kernel_size=4, strides=2, padding="same", use_bias=False
)(x)
x = layers.BatchNormalization(momentum=0.9)(x)
x = layers.LeakyReLU(0.2)(x)
x = layers.Conv2DTranspose(
    128, kernel_size=4, strides=2, padding="same", use_bias=False
)(x)
x = layers.BatchNormalization(momentum=0.9)(x)
x = layers.LeakyReLU(0.2)(x)
x = layers.Conv2DTranspose(
    64, kernel_size=4, strides=2, padding="same", use_bias=False
)(x)
x = layers.BatchNormalization(momentum=0.9)(x)
x = layers.LeakyReLU(0.2)(x)
generator_output = layers.Conv2DTranspose(
    CHANNELS,
    kernel_size=4,
    strides=2,
    padding="same",
    use_bias=False,
    activation="tanh",
)(x)
generator = models.Model(generator_input, generator_output)
generator.summary()
# Out:
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)      │ (None, 100)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape (Reshape)               │ (None, 1, 1, 100)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose                │ (None, 4, 4, 512)      │       819,200 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 4, 4, 512)      │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_8 (LeakyReLU)       │ (None, 4, 4, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_1              │ (None, 8, 8, 256)      │     2,097,152 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 8, 8, 256)      │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_9 (LeakyReLU)       │ (None, 8, 8, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_2              │ (None, 16, 16, 128)    │       524,288 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_8           │ (None, 16, 16, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_10 (LeakyReLU)      │ (None, 16, 16, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_3              │ (None, 32, 32, 64)     │       131,072 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_9           │ (None, 32, 32, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_11 (LeakyReLU)      │ (None, 32, 32, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_4              │ (None, 64, 64, 1)      │         1,024 │
# │ (Conv2DTranspose)               │                        │               │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,576,576 (13.64 MB)
#  Trainable params: 3,574,656 (13.64 MB)
#  Non-trainable params: 1,920 (7.50 KB)

# %%
class DCGAG(models.Model):
    def __init__(self,discriminator,generator,latent_dim):
        super(DCGAN,self).__init__()
        self.discriminator = discriminator
        self.generator = generator
        self.latent_dim = latent_dim

    def compile(self,d_optimizer,g_optimizer):
        super(DGGAN,self).__init__()
        self.loss_fn = losses.BinaryCrossentropy()

        self.d_optimizer = d_optimizer
        self.g_optimizer = g_optimizer

        self.d_loss_metric = metrics.Mean(name='d_loss')
        self.d_real_acc_metric = metrics.BinaryAccuracy(name='d_real_acc')
        self.d_fake_acc_metric = metrics.BinaryAccuracy(name='d_fake_acc')
        self.d_acc_metric = metrics.BinaryAccuracy(name='d_acc')
        self.g_loss_metric = metrics.Mean(name='g_loss')
        self.g_acc_metric = metrics.BinaryAccuracy(name='g_acc')

    @property
    def metrics(self):
        return[
            self.d_loss_metric,
            self.d_real_acc_metric,
            self.d_fake_acc_metric,
            self.d_acc_metric,
            self.g_loss_metric,
            self.g_acc_metric
        ]

    def train_step(self,real_images):
        batch_size = tf.shape(real_images]
        random_latent_vectors = tf.random.normal(
            shape=(batch_size,self.latent_dim)
        )
        with tf.GradientTape() as gen_tape,tf.GradientTape() as disc_tape:
            generated_images = self.generator(
                random_latent_vectors , training=True
            )
            real_predictions = self.discriminator(real_images,training=True)
            fake_predictions = self.discriminator(generated_images,training=True)

            real_labels = tf.ones_like(real_predictions)
            real_noisy_labels = real_labels + NOISE_PARAM * tf.random.uniform(tf.shape(real_predictions))

            fake_labels = tf.zeros_like(fake_predictions)
            fake_noisy_labels = fake_labels - NOISE_PARAM * tf.random.uniform(tf.shape(fake_predictions))

            d_real_loss = self.loss_fn(real_noisy_labels,real_predictions)
            d_fake_loss = self.loss_fn(fake_noisy_labels,fake_predictions)
            d_loss = (d_real_loss + d_fake_loss) / 2.0

            g_loss = self.loss_fn(real_labels,fake_predictions)
